# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("covid19_tr.csv",sep=";")
data
# Out:
#     vaka_yeni  vaka_toplam  olum_yeni  ...  test_toplam       tarih  vaka_gun
# 0           1            1          0  ...          NaN  2020-03-11         1
# 1           0            1          0  ...          NaN  2020-03-12         2
# 2           4            5          0  ...          NaN  2020-03-13         3
# 3           1            6          0  ...          NaN  2020-03-14         4
# 4          12           18          1  ...          NaN  2020-03-15         5
# 5          29           47          0  ...          NaN  2020-03-16         6
# 6          41           98          1  ...       8002.0  2020-03-17         7
# 7          93          191          2  ...      10017.0  2020-03-18         8
# 8         168          359          1  ...      11998.0  2020-03-19         9
# 9         311          670          5  ...      15624.0  2020-03-20        10
# 10        277          947         13  ...      18604.0  2020-03-21        11
# ...

# %%
from google.colab import files
data_to_load=files.upload()
# Out:
#      <input type="file" id="files-d8dd0d29-1ff4-412a-a09c-6a3183ced0ed" name="files[]" multiple disabled />
#      <output id="result-d8dd0d29-1ff4-412a-a09c-6a3183ced0ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid19_tr.csv to covid19_tr.csv

# %%
data.head()
# Out:
#    vaka_yeni  vaka_toplam  olum_yeni  ...  test_toplam       tarih  vaka_gun
# 0          1            1          0  ...          NaN  2020-03-11         1
# 1          0            1          0  ...          NaN  2020-03-12         2
# 2          4            5          0  ...          NaN  2020-03-13         3
# 3          1            6          0  ...          NaN  2020-03-14         4
# 4         12           18          1  ...          NaN  2020-03-15         5
#
# [5 rows x 11 columns]

# %%
data.tail()
# Out:
#     vaka_yeni  vaka_toplam  olum_yeni  ...  test_toplam       tarih  vaka_gun
# 35       4281        69392        115  ...     477716.0  2020-04-15        36
# 36       4801        74193        125  ...     518143.0  2020-04-16        37
# 37       4353        78546        126  ...     558413.0  2020-04-17        38
# 38       3783        82329        121  ...     598933.0  2020-04-18        39
# 39       3977        86306        127  ...     634277.0  2020-04-19        40
#
# [5 rows x 11 columns]

# %%
data.columns
# Out:
# Index(['vaka_yeni', 'vaka_toplam', 'olum_yeni', 'olum_toplam', 'iyilesen_yeni',
#        'iyilesen_toplam', 'entube', 'test_yeni', 'test_toplam', 'tarih',
#        'vaka_gun'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   vaka_yeni        40 non-null     int64
#  1   vaka_toplam      40 non-null     int64
#  2   olum_yeni        40 non-null     int64
#  3   olum_toplam      40 non-null     int64
#  4   iyilesen_yeni    24 non-null     float64
#  5   iyilesen_toplam  25 non-null     float64
#  6   entube           25 non-null     float64
#  7   test_yeni        33 non-null     float64
#  8   test_toplam      34 non-null     float64
#  9   tarih            40 non-null     object
#  10  vaka_gun         40 non-null     int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 3.6+ KB

# %%
data.describe()
# Out:
#          vaka_yeni   vaka_toplam  ...    test_toplam   vaka_gun
# count    40.000000     40.000000  ...      34.000000  40.000000
# mean   2157.400000  24588.675000  ...  202354.588235  20.500000
# std    1810.211559  28114.255927  ...  195297.549893  11.690452
# min       0.000000      1.000000  ...    8002.000000   1.000000
# 25%     286.000000    877.750000  ...   34825.500000  10.750000
# 50%    2108.500000  12179.000000  ...  133636.000000  20.500000
# 75%    3996.750000  43468.750000  ...  332087.500000  30.250000
# max    5138.000000  86306.000000  ...  634277.000000  40.000000
#
# [8 rows x 10 columns]

# %%
data.mean()
# Out:
# vaka_yeni            2157.400000
# vaka_toplam         24588.675000
# olum_yeni              50.475000
# olum_toplam           526.675000
# iyilesen_yeni         497.916667
# iyilesen_toplam      2880.680000
# entube                829.760000
# test_yeni           18978.030303
# test_toplam        202354.588235
# vaka_gun               20.500000
# dtype: float64

# %%
data.median()
# Out:
# vaka_yeni            2108.5
# vaka_toplam         12179.0
# olum_yeni              41.5
# olum_toplam           191.0
# iyilesen_yeni         282.5
# iyilesen_toplam      1582.0
# entube                978.0
# test_yeni           18757.0
# test_toplam        133636.0
# vaka_gun               20.5
# dtype: float64

# %%
data.sum()
# Out:
# vaka_yeni                                                      86296
# vaka_toplam                                                   983547
# olum_yeni                                                       2019
# olum_toplam                                                    21067
# iyilesen_yeni                                                  11950
# iyilesen_toplam                                                72017
# entube                                                         20744
# test_yeni                                                     626275
# test_toplam                                              6.88006e+06
# tarih              2020-03-112020-03-122020-03-132020-03-142020-0...
# vaka_gun                                                         820
# dtype: object

# %%
data.max()
# Out:
# vaka_yeni                5138
# vaka_toplam             86306
# olum_yeni                 127
# olum_toplam              2017
# iyilesen_yeni            1822
# iyilesen_toplam         11976
# entube                   1087
# test_yeni               40520
# test_toplam            634277
# tarih              2020-04-19
# vaka_gun                   40
# dtype: object

# %%
data.min()
# Out:
# vaka_yeni                   0
# vaka_toplam                 1
# olum_yeni                   0
# olum_toplam                 0
# iyilesen_yeni              16
# iyilesen_toplam            26
# entube                    102
# test_yeni                1738
# test_toplam              8002
# tarih              2020-03-11
# vaka_gun                    1
# dtype: object

# %%
data.std()
# Out:
# vaka_yeni            1810.211559
# vaka_toplam         28114.255927
# olum_yeni              45.954262
# olum_toplam           630.545160
# iyilesen_yeni         547.754223
# iyilesen_toplam      3427.711818
# entube                293.793051
# test_yeni           13305.009798
# test_toplam        195297.549893
# vaka_gun               11.690452
# dtype: float64

# %%
data.count()
# Out:
# vaka_yeni          40
# vaka_toplam        40
# olum_yeni          40
# olum_toplam        40
# iyilesen_yeni      24
# iyilesen_toplam    25
# entube             25
# test_yeni          33
# test_toplam        34
# tarih              40
# vaka_gun           40
# dtype: int64

# %%
data1=data.drop("tarih",axis=1)
data1.plot()
plt.show()

# %%
plt.figure(figsize=(15,6))

plt.plot(data.vaka_gun,data.test_toplam)
plt.title("TEST")
plt.xlabel("zaman")
plt.ylabel("Test sayısı")
plt.show()

# %%
plt.figure(figsize=(15,6))

plt.plot(data.vaka_gun,data.vaka_toplam)
plt.title("vaka")
plt.xlabel("zaman")
plt.ylabel("vaka sayısı")
plt.show()

# %%
plt.figure(figsize=(15,6))

plt.plot(data.vaka_gun,data.olum_toplam)
plt.title("ÖLÜM")
plt.xlabel("zaman")
plt.ylabel("ölüm sayısı")
plt.show()

# %%
plt.figure(figsize=(15,6))

plt.plot(data.vaka_gun,data.iyilesen_toplam)
plt.title("iyilesen")
plt.xlabel("zaman")
plt.ylabel("iyilesen sayısı")
plt.show()
